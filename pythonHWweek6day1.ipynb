# %%
import pandas as pd
from matplotlib.pyplot import boxplot, plot
import missingno as msno
from pandas import get_dummies

# %%
data = pd.read_csv('C:/Users/ADMIN/Downloads/loan_prediction.csv')
df = data.copy()
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_388\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
new_target = get_dummies(df['Loan_Status'], drop_first=True)
df.drop('Loan_Status', axis=1)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# df.drop('Y', axis=1, inplace=True)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = pd.concat([df, new_target], axis=1)
# df.drop('Y', inplace=True, axis=1)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Loan_Status']
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
df.isnull().sum()
df.drop('Credit_History', inplace=True, axis=1)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# Loan_Status           0
# Y                     0
# dtype: int64

# %%
df.drop('Loan_Status', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Property_Area', 'Y'],
#       dtype='object')

# %%
# df['Gender'].fillna(method=

# %%
df['gender_male'] = get_dummies(df['Gender'], drop_first=True)
df.drop(columns='Gender', inplace=True, axis=1)
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df.drop('Y', inplace=True, axis=1)

# %%
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# gender_male           0
# dtype: int64

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_388\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# gender_male               0.013933           0.082316    0.065501
#
#                    Loan_Amount_Term  gender_male
# ApplicantIncome           -0.045306     0.013933
# CoapplicantIncome         -0.059878     0.082316
# LoanAmount                 0.039447     0.065501
# Loan_Amount_Term           1.000000    -0.071026
# ...

# %%
dataframe = data.copy()

# %%
target= get_dummies(dataframe['Loan_Status'], drop_first=True)

# %%
df['Target'] = target

# %%
df['Target']
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Target, Length: 614, dtype: uint8

# %%
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# gender_male           0
# Target                0
# dtype: int64

# %%
df.drop('Self_Employed', axis=1, inplace=True)

# %%
df
# Out:
#       Loan_ID Married Dependents     Education  ApplicantIncome  \
# 0    LP001002      No          0      Graduate             5849
# 1    LP001003     Yes          1      Graduate             4583
# 2    LP001005     Yes          0      Graduate             3000
# 3    LP001006     Yes          0  Not Graduate             2583
# 4    LP001008      No          0      Graduate             6000
# ..        ...     ...        ...           ...              ...
# 609  LP002978      No          0      Graduate             2900
# 610  LP002979     Yes         3+      Graduate             4106
# 611  LP002983     Yes          1      Graduate             8072
# 612  LP002984     Yes          2      Graduate             7583
# 613  LP002990      No          0      Graduate             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area  \
# 0                  0.0         NaN             360.0         Urban
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Married               3
# Dependents           15
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# gender_male           0
# Target                0
# dtype: int64

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_388\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# gender_male               0.013933           0.082316    0.065501
# Target                   -0.004710          -0.059187   -0.037318
#
#                    Loan_Amount_Term  gender_male    Target
# ApplicantIncome           -0.045306     0.013933 -0.004710
# CoapplicantIncome         -0.059878     0.082316 -0.059187
# ...

# %%
df['Married'].nunique()
# Out:
# 2

# %%
df['married'] = get_dummies(df['Married'], drop_first=True)

# %%
df['married']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: married, Length: 614, dtype: uint8

# %%
df['married'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       Loan_ID Married Dependents     Education  ApplicantIncome  \
# 0    LP001002      No          0      Graduate             5849
# 1    LP001003     Yes          1      Graduate             4583
# 2    LP001005     Yes          0      Graduate             3000
# 3    LP001006     Yes          0  Not Graduate             2583
# 4    LP001008      No          0      Graduate             6000
# ..        ...     ...        ...           ...              ...
# 609  LP002978      No          0      Graduate             2900
# 610  LP002979     Yes         3+      Graduate             4106
# 611  LP002983     Yes          1      Graduate             8072
# 612  LP002984     Yes          2      Graduate             7583
# 613  LP002990      No          0      Graduate             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area  \
# 0                  0.0         NaN             360.0         Urban
# ...

# %%
df.drop('Married', inplace=True, axis=1)
df
# Out:
#       Loan_ID Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0    LP001002          0      Graduate             5849                0.0
# 1    LP001003          1      Graduate             4583             1508.0
# 2    LP001005          0      Graduate             3000                0.0
# 3    LP001006          0  Not Graduate             2583             2358.0
# 4    LP001008          0      Graduate             6000                0.0
# ..        ...        ...           ...              ...                ...
# 609  LP002978          0      Graduate             2900                0.0
# 610  LP002979         3+      Graduate             4106                0.0
# 611  LP002983          1      Graduate             8072              240.0
# 612  LP002984          2      Graduate             7583                0.0
# 613  LP002990          0      Graduate             4583                0.0
#
# ...

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_388\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# gender_male               0.013933           0.082316    0.065501
# Target                   -0.004710          -0.059187   -0.037318
# married                   0.050194           0.080496    0.148367
#
#                    Loan_Amount_Term  gender_male    Target   married
# ApplicantIncome           -0.045306     0.013933 -0.004710  0.050194
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Dependents', 'Education', 'ApplicantIncome',
#        'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Property_Area',
#        'gender_male', 'Target', 'married'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Dependents           15
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# gender_male           0
# Target                0
# married               0
# dtype: int64

# %%
print(df['Education'].nunique())
print(df['Dependents'].nunique())
# Out:
# 2
# 4

# %%
df.drop(['LoanAmount', 'Loan_Amount_Term', 'Dependents'], inplace=True, axis=1)

# %%
df
# Out:
#       Loan_ID     Education  ApplicantIncome  CoapplicantIncome Property_Area  \
# 0    LP001002      Graduate             5849                0.0         Urban
# 1    LP001003      Graduate             4583             1508.0         Rural
# 2    LP001005      Graduate             3000                0.0         Urban
# 3    LP001006  Not Graduate             2583             2358.0         Urban
# 4    LP001008      Graduate             6000                0.0         Urban
# ..        ...           ...              ...                ...           ...
# 609  LP002978      Graduate             2900                0.0         Rural
# 610  LP002979      Graduate             4106                0.0         Rural
# 611  LP002983      Graduate             8072              240.0         Urban
# 612  LP002984      Graduate             7583                0.0         Urban
# 613  LP002990      Graduate             4583                0.0     Semiurban
#
# ...

# %%
education_level = get_dummies(df['Education'], drop_first=True)

# %%
df =pd.concat([df, education_level], axis=1)

# %%
df.drop('Education', inplace=True, axis=1)

# %%
df
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome Property_Area  gender_male  \
# 0    LP001002             5849                0.0         Urban            1
# 1    LP001003             4583             1508.0         Rural            1
# 2    LP001005             3000                0.0         Urban            1
# 3    LP001006             2583             2358.0         Urban            1
# 4    LP001008             6000                0.0         Urban            1
# ..        ...              ...                ...           ...          ...
# 609  LP002978             2900                0.0         Rural            0
# 610  LP002979             4106                0.0         Rural            1
# 611  LP002983             8072              240.0         Urban            1
# 612  LP002984             7583                0.0         Urban            1
# 613  LP002990             4583                0.0     Semiurban            0
#
#      Target  married  Not Graduate
# ...

# %%
df['Property_Area'].nunique()
# Out:
# 3

# %%
area_type = get_dummies(df['Property_Area'], drop_first=True)

# %%
df = pd.concat([df, area_type], axis=1)

# %%
df
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome Property_Area  gender_male  \
# 0    LP001002             5849                0.0         Urban            1
# 1    LP001003             4583             1508.0         Rural            1
# 2    LP001005             3000                0.0         Urban            1
# 3    LP001006             2583             2358.0         Urban            1
# 4    LP001008             6000                0.0         Urban            1
# ..        ...              ...                ...           ...          ...
# 609  LP002978             2900                0.0         Rural            0
# 610  LP002979             4106                0.0         Rural            1
# 611  LP002983             8072              240.0         Urban            1
# 612  LP002984             7583                0.0         Urban            1
# 613  LP002990             4583                0.0     Semiurban            0
#
# ...

# %%
df.drop('Property_Area', inplace=True, axis=1)

# %%
df
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  gender_male  Target  \
# 0    LP001002             5849                0.0            1       1
# 1    LP001003             4583             1508.0            1       0
# 2    LP001005             3000                0.0            1       1
# 3    LP001006             2583             2358.0            1       1
# 4    LP001008             6000                0.0            1       1
# ..        ...              ...                ...          ...     ...
# 609  LP002978             2900                0.0            0       1
# 610  LP002979             4106                0.0            1       1
# 611  LP002983             8072              240.0            1       1
# 612  LP002984             7583                0.0            1       1
# 613  LP002990             4583                0.0            0       0
#
#      married  Not Graduate  Semiurban  Urban
# 0          0             0          0      1
# ...

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_388\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  gender_male    Target  \
# ApplicantIncome           1.000000          -0.116605     0.013933 -0.004710
# CoapplicantIncome        -0.116605           1.000000     0.082316 -0.059187
# gender_male               0.013933           0.082316     1.000000  0.025407
# Target                   -0.004710          -0.059187     0.025407  1.000000
# married                   0.050194           0.080496     0.339026  0.084281
# Not Graduate             -0.140760          -0.062290     0.061497 -0.085884
# Semiurban                -0.014246          -0.027044    -0.113069  0.136540
# ...

# %%
df['target'] = df['Target']

# %%
df.drop('Target', inplace=True, axis=1)

# %%
df.drop('Loan_ID', inplace=True, axis=1)

# %%
df
# Out:
#      ApplicantIncome  CoapplicantIncome  gender_male  married  Not Graduate  \
# 0               5849                0.0            1        0             0
# 1               4583             1508.0            1        1             0
# 2               3000                0.0            1        1             0
# 3               2583             2358.0            1        1             1
# 4               6000                0.0            1        0             0
# ..               ...                ...          ...      ...           ...
# 609             2900                0.0            0        0             0
# 610             4106                0.0            1        1             0
# 611             8072              240.0            1        1             0
# 612             7583                0.0            1        1             0
# 613             4583                0.0            0        0             0
#
#      Semiurban  Urban  target
# ...

# %% [markdown]
# <h1>Voting Soft</h1>

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
df.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# gender_male          0
# married              0
# Not Graduate         0
# Semiurban            0
# Urban                0
# target               0
# dtype: int64

# %%
model1 = SVC(probability=True)
model2 = LogisticRegression()
model3 = DecisionTreeClassifier()

# %%
x = df.iloc[:, 0:7]
y = df.iloc[:,  -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
voting_soft = VotingClassifier(estimators=[('svc', model1),
                                           ('lr', model2), 
                                           ('dt', model3)],
                               voting='soft')

# %%
voting_soft.fit(x_train, y_train)
# Out:
# VotingClassifier(estimators=[('svc', SVC(probability=True)),
#                              ('lr', LogisticRegression()),
#                              ('dt', DecisionTreeClassifier())],
#                  voting='soft')

# %%
voting_soft_pred = voting_soft.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, voting_soft_pred)
# Out:
# 0.6270270270270271

# %%
# help(VotingClassifier)

# %% [markdown]
# <h1>Voting Hard</h1>

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
x = df.iloc[:, 0:7]
y = df.iloc[:,  -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
model1 = SVC()
model2 = DecisionTreeClassifier()
model3 = LogisticRegression()

# %%
voting_hard = VotingClassifier(estimators=[('svm', model1), ('dt', model2), ('lr', model3)], voting='hard')

# %%
voting_hard.fit(x_train, y_train)
# Out:
# VotingClassifier(estimators=[('svm', SVC()), ('dt', DecisionTreeClassifier()),
#                              ('lr', LogisticRegression())])

# %%
voting_hard_pred = voting_hard.predict(x_test)

# %%
accuracy_score(y_test, voting_hard_pred)
# Out:
# 0.654054054054054

# %% [markdown]
# <h1>Bagging Classifier</h1>

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
estimators = SVC(probability=True)
bagging_classifier = BaggingClassifier(estimator=estimators, n_estimators=10, max_samples=0.4,
                        bootstrap=True, bootstrap_features=True, n_jobs=-1, random_state=123)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
bagging_classifier.fit(x_train, y_train)
# Out:
# BaggingClassifier(bootstrap_features=True, estimator=SVC(probability=True),
#                   max_samples=0.4, n_jobs=-1, random_state=123)

# %%
bagging_pred = bagging_classifier.predict(x_test)

# %%
accuracy_score(y_test, bagging_pred)
# Out:
# 0.654054054054054

# %% [markdown]
# <h1>Gradient Boosting Classifier</h1>

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
gbc = GradientBoostingClassifier(random_state=101)

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=101)

# %%
gbc_pred = gbc.predict(x_test)

# %%
accuracy_score(gbc_pred, y_test)
# Out:
# 0.6324324324324324

# %% [markdown]
# <h1>XGBoost</h1>

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
xgbt = XGBClassifier()

# %%
xgbt.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgbt_pred = xgbt.predict(x_test)

# %%
accuracy_score(xgbt_pred, y_test)
# Out:
# 0.6162162162162163

# %% [markdown]
# <h1>CatBoost</h1>

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
cbc = CatBoostClassifier()

# %%
cbc.fit(x_train, y_train)
# Out:
# Learning rate set to 0.007178
# 0:	learn: 0.6910471	total: 151ms	remaining: 2m 30s
# 1:	learn: 0.6888948	total: 153ms	remaining: 1m 16s
# 2:	learn: 0.6871634	total: 155ms	remaining: 51.5s
# 3:	learn: 0.6856611	total: 157ms	remaining: 39s
# 4:	learn: 0.6838717	total: 159ms	remaining: 31.6s
# 5:	learn: 0.6824844	total: 161ms	remaining: 26.7s
# 6:	learn: 0.6810664	total: 163ms	remaining: 23.2s
# 7:	learn: 0.6792117	total: 166ms	remaining: 20.6s
# 8:	learn: 0.6777118	total: 168ms	remaining: 18.5s
# 9:	learn: 0.6762559	total: 171ms	remaining: 16.9s
# 10:	learn: 0.6743353	total: 172ms	remaining: 15.5s
# 11:	learn: 0.6728737	total: 174ms	remaining: 14.3s
# 12:	learn: 0.6710408	total: 176ms	remaining: 13.4s
# 13:	learn: 0.6696420	total: 178ms	remaining: 12.5s
# 14:	learn: 0.6676970	total: 180ms	remaining: 11.8s
# 15:	learn: 0.6666289	total: 181ms	remaining: 11.2s
# 16:	learn: 0.6651591	total: 183ms	remaining: 10.6s
# 17:	learn: 0.6630445	total: 185ms	remaining: 10.1s
# ...

# %%
cbc_pred = cbc.predict(x_test)

# %%
accuracy_score(cbc_pred, y_test)
# Out:
# 0.6486486486486487

# %% [markdown]
# <h1>LightGBM</h1>

# %%
# !pip install lightgbm
# Out:
# ...
#      ---------------------------------------- 1.3/1.3 MB 126.2 kB/s eta 0:00:00
# ...

# %%
import lightgbm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
x = df.iloc[:, 0:7]
y = df.iloc[:,  -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=101, test_size=0.3)

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
lgb = lightgbm

# %%
y_train
# Out:
# 416    0
# 338    0
# 288    1
# 314    0
# 181    0
#       ..
# 75     0
# 599    1
# 575    1
# 337    1
# 523    1
# Name: target, Length: 429, dtype: uint8
